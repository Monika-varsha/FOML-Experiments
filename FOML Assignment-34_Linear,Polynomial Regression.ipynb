# %% [raw]
# Linear Regression using Employee_data dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df = pd.read_csv('employee_data.csv')

# %%
df.dropna(inplace=True)

# %%
xpoints = df["Experience (Years)"].values.reshape(-1, 1)
ypoints = df["Salary"].values

# %%
x_train, x_test, y_train, y_test = train_test_split(xpoints, ypoints, test_size=0.1, random_state=42)

# %%
reg = linear_model.LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypoints_pred = reg.predict(x_test)

# %%
plt.scatter(x_test, y_test, color="red", label="Actual")
plt.plot(x_test, ypoints_pred, color="blue", label="Predicted")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Linear Regression: Experience (Years) vs Salary")
# Out:
# Text(0.5, 1.0, 'Linear Regression: Experience (Years) vs Salary')

# %% [raw]
# Polynomial Regression using Employee_data dataset

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('employee_data.csv')

# %%
df.dropna(inplace=True)

# %%
xpoints = df["Experience (Years)"].values.reshape(-1, 1)
ypoints = df["Salary"].values

# %%
x_train, x_test, y_train, y_test = train_test_split(xpoints, ypoints, test_size=0.1, random_state=42)

# %%
degree = 2 
poly_features = PolynomialFeatures(degree=degree)
x_train_poly = poly_features.fit_transform(x_train)
x_test_poly = poly_features.transform(x_test)

# %%
poly_reg = LinearRegression()
poly_reg.fit(x_train_poly, y_train)
# Out:
# LinearRegression()

# %%
ypoints_pred = poly_reg.predict(x_test_poly)

# %%
rmse = np.sqrt(mean_squared_error(y_test, ypoints_pred))
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 34303.269613311364

# %%
plt.scatter(x_test, y_test, color="red", label="Actual")
plt.scatter(x_test, ypoints_pred, color="blue", label="Predicted (Polynomial Regression)")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Polynomial Regression: Experience (Years) vs Salary")
plt.legend()
plt.show()
